# %% [markdown]
# ![playing-cards.png](attachment:playing-cards.png)
# ## Questions for Investigation
#
# This experiment will require the use of a standard deck of playing cards. This is a deck of fifty-two cards divided into four suits (spades (♠), hearts (♥), diamonds (♦), and clubs (♣)), each suit containing thirteen cards (Ace, numbers 2-10, and face cards Jack, Queen, and King). You can use either a physical deck of cards for this experiment or you may use our data generator in the Generate Data section, or a virtual deck of cards such as that found on random.org(http://www.random.org/playing-cards/).
#
# For the purposes of this task, assign each card a value: The Ace takes a value of 1, numbered cards take the value printed on the card, and the Jack, Queen, and King each take a value of 10.
#
# For the rest of the lesson, you will do the following:
#
# **Distribution of Card Values:** In this section, you'll create a histogram and answer quiz questions about the distribution of card values.
#
# **Generate Data:** In this section, you will get samples for a new distribution. To obtain a single sample, shuffle your deck of cards and draw three cards from it. (You will be sampling from the deck without replacement.) Record the cards that you have drawn and the sum of the three cards’ values. Replace the drawn cards back into the deck and repeat this sampling procedure a total of at least thirty times.
#
# **Create Write-up:** You'll create a summary of your findings.
#
# **Evaluate Answers:** You'll compare your results to those from a computer program that automatically generates the results.
#
# And the steps to summarize the findings as:
#
# 1.First, create a histogram depicting the relative frequencies of the card values for a single draw. Report the mean, median, and standard deviation of the value distribution. (You should have performed this step in the Distribution of Card Values section.)
#
# 2.Take a look at the distribution of the three-card sums from the samples that you obtained, either from Generate Data, or from your own collection. Report descriptive statistics for the samples you have drawn. Include at least two measures of central tendency and two measures of variability.
#
# 3.reate a histogram of the sampled three-card sums. Compare its shape to that of the original distribution. How are they different, and can you explain why this is the case?
#
# 4.Make some estimates about values you would get on future draws. Within what range will you expect approximately 90% of your draw values to fall? What is the approximate probability that you will get a draw value of at least 20? Make sure you justify how you obtained your values.

# %% [markdown]
# ### Distribution of Card Values
# To begin, make a histogram representing the relative frequencies of the card values from a single draw.
#
# ![image.png](attachment:image.png)
# And we have the mean of the card values for a single draw is 6.54, the median is 7 and standard deviation is 3.15.

# %% [markdown]
# ### Repeatedly Sample the Deck and Report Descriptive Statistics
# From the sample the deck result, we obtain a set of 30 times try of three-card. The reported descriptie statics for the samples I drawn and the distribution as below:
#
# |Measures of Central Tendency|     Value      |
# |:---------|:----------------|
# |Mean     |     19.87      |
# |Median   |     19         |
# |Mode     |     18         |
#
# |Measures of variation|     Value      |
# |:---------|:----------------|
# |IQR     |     8      |
# |Variance   |     23.22        |
# |Standard Deviation     |      4.82     |
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The original distribution was highly skewed, and the sample data was less skewed. The distribution of sample values is normal (here only n=30, if we got n larger, for example 1000, we will have a better normal distribution). This is because the distribution of sample means (or in this case, sums) is normal for any population. This is given by The Central Limit Theorem.

# %% [markdown]
# ### Estimates about Future Draws
# Make some estimates about values you would get on future draws. Within what range will you expect approximately 90% of your draw values to fall? What is the approximate probability that you will get a draw value of at least 20? Make sure you justify how you obtained your values.
#
# 1. Within what range will you expect approximately 90% of your draw values to fall?
#
# 90% of the draw values should fall within the area that exclude left most 5% and right most 5%. And the related Z-score are -1.635 and 1.635. Since the estimated standard deviation is 4.82 and the mean is 19.87 so the range should be 12<X<28.
#
# 2. What is the approximate probability that you will get a draw value of at least 20?
#
# Base on the estimated mean and standard deviation, from 20 we obtained a Z-score as 0.027. From the Z-table, we got a probability as 0.5120. Therefore, the probability that we will get a draw value of at least 20 is: 1 - 0.5120 = 0.488.
